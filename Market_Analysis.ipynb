# %% [markdown]
# <a href="https://colab.research.google.com/github/Augusta02/Machine-Learning-Projects/blob/main/Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-51955cad-b005-45a6-af38-b794622818fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51955cad-b005-45a6-af38-b794622818fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Market_Basket_Optimisation.csv to Market_Basket_Optimisation.csv

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  ...  Shirt  Skirt  Sneakers  Sunglasses
# 0  False     False   True  False  ...  False   True      True       False
# 1  False     False   True  False  ...  False   True      True        True
# 2   True     False  False   True  ...  False  False     False       False
# 3   True      True   True   True  ...  False  False     False       False
# 4  False      True  False  False  ...   True   True     False       False
#
# [5 rows x 12 columns]

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Skirt, Pants)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70
# Out:
#   antecedents consequents  antecedent support  ...    lift  leverage  conviction
# 0     (Scarf)     (Pants)                 0.8  ...  0.9375     -0.04         0.8
# 1     (Pants)     (Scarf)                 0.8  ...  0.9375     -0.04         0.8
# 2     (Skirt)     (Pants)                 0.6  ...  1.2500      0.12         inf
# 3     (Pants)     (Skirt)                 0.8  ...  1.2500      0.12         1.6
#
# [4 rows x 9 columns]

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  ...  lift  leverage  conviction
# 0     (Skirt)     (Pants)                 0.6  ...  1.25      0.12         inf
#
# [1 rows x 9 columns]

# %%
import pandas as pd

# %%
df= pd.read_csv("Market_Basket_Optimisation.csv", delimiter= ",", header= None)

# %%
df.head()
# Out:
#               0          1           2   ...               17       18         19
# 0         shrimp    almonds     avocado  ...  frozen smoothie  spinach  olive oil
# 1        burgers  meatballs        eggs  ...              NaN      NaN        NaN
# 2        chutney        NaN         NaN  ...              NaN      NaN        NaN
# 3         turkey    avocado         NaN  ...              NaN      NaN        NaN
# 4  mineral water       milk  energy bar  ...              NaN      NaN        NaN
#
# [5 rows x 20 columns]

# %%
import numpy as np

# %%
df_res = pd.DataFrame()
for i in range(len(df.columns)):
    df_res = df_res.append(df[i].value_counts()) 
df_res.head(5)
# Out:
#    almonds  antioxydant juice  asparagus  ...  water spray  zucchini  napkins
# 0     11.0               18.0        3.0  ...          NaN       NaN      NaN
# 1     29.0               10.0        2.0  ...          1.0      10.0      NaN
# 2     35.0               12.0        5.0  ...          1.0       2.0      NaN
# 3     29.0                6.0        4.0  ...          1.0       9.0      1.0
# 4     12.0                3.0        4.0  ...          NaN      17.0      2.0
#
# [5 rows x 119 columns]

# %%
df_sum = df_res.sum()
df_sum = df_sum.sort_values(ascending=False)
df_sum
# Out:
# mineral water    1788.0
# eggs             1348.0
# spaghetti        1306.0
# french fries     1282.0
# chocolate        1230.0
#                   ...
# tea                29.0
# bramble            14.0
# cream               7.0
# napkins             5.0
# water spray         3.0
# Length: 119, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,8))
plt.title("FREQUENCY PLOT")
cnt = 45 # plot only first 'cnt' values
color = plt.cm.spring(np.linspace(0, 1, cnt))
df_sum.head(cnt).plot.bar(color = color)
plt.xticks(rotation = 'vertical')
plt.grid(False)
plt.axis('on')
plt.show()

# %%
# !pip install squarify
# import squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import squarify

# %%
plt.figure(figsize=(15,15))
cnt = 40 # plot only first 'cnt' values
color = plt.cm.hot(np.linspace(0, 1, cnt))
df_part = df_sum.head(cnt)
squarify.plot(sizes = df_part.values, label = df_part.index, alpha=.8, color = color, text_kwargs={'fontsize':8})
plt.axis('off')
plt.show()

# %%
arr = []
for i in range(df.shape[0]):
    arr.append([str(df.values[i,j]) for j in range(df.shape[1])])

arr = np.array(arr)

# %%
te = TransactionEncoder()
data = te.fit_transform(arr)
data = pd.DataFrame(data, columns = te.columns_)
data
# Out:
#       almonds  antioxydant juice  asparagus  ...   yams  yogurt cake  zucchini
# 0        True               True      False  ...   True        False     False
# 1       False              False      False  ...  False        False     False
# 2       False              False      False  ...  False        False     False
# 3       False              False      False  ...  False        False     False
# 4       False              False      False  ...  False        False     False
# ...       ...                ...        ...  ...    ...          ...       ...
# 7496    False              False      False  ...  False        False     False
# 7497    False              False      False  ...  False        False     False
# 7498    False              False      False  ...  False        False     False
# 7499    False              False      False  ...  False        False     False
# 7500    False              False      False  ...  False         True     False
#
# [7501 rows x 120 columns]

# %%
data = data.drop(columns=['nan'])
data.head(5)
# Out:
#    almonds  antioxydant juice  asparagus  ...   yams  yogurt cake  zucchini
# 0     True               True      False  ...   True        False     False
# 1    False              False      False  ...  False        False     False
# 2    False              False      False  ...  False        False     False
# 3    False              False      False  ...  False        False     False
# 4    False              False      False  ...  False        False     False
#
# [5 rows x 119 columns]

# %%
freq_rules = apriori(data, min_support = 0.01, use_colnames = True)
freq_rules
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (ground beef, milk, mineral water)
# 253  0.017064  (ground beef, spaghetti, mineral water)
# 254  0.015731         (milk, spaghetti, mineral water)
# 255  0.010265    (spaghetti, mineral water, olive oil)
# 256  0.011465     (pancakes, spaghetti, mineral water)
#
# [257 rows x 2 columns]

# %%
freq_rules['length'] = freq_rules['itemsets'].apply(lambda x: len(x))
freq_rules
# Out:
#       support                                 itemsets  length
# 0    0.020397                                (almonds)       1
# 1    0.033329                                (avocado)       1
# 2    0.010799                         (barbecue sauce)       1
# 3    0.014265                              (black tea)       1
# 4    0.011465                             (body spray)       1
# ..        ...                                      ...     ...
# 252  0.011065       (ground beef, milk, mineral water)       3
# 253  0.017064  (ground beef, spaghetti, mineral water)       3
# 254  0.015731         (milk, spaghetti, mineral water)       3
# 255  0.010265    (spaghetti, mineral water, olive oil)       3
# 256  0.011465     (pancakes, spaghetti, mineral water)       3
#
# [257 rows x 3 columns]

# %%
freq_rules[ (freq_rules['length'] == 2) &
                   (freq_rules['support'] >= 0.05) ]
# Out:
#       support                    itemsets  length
# 118  0.052660  (chocolate, mineral water)       2
# 144  0.050927       (eggs, mineral water)       2
# 224  0.059725  (spaghetti, mineral water)       2

# %%
freq_rules[ (freq_rules['length'] == 1) &
                   (freq_rules['support'] >= 0.05) ]
# Out:
#      support             itemsets  length
# 6   0.087188            (burgers)       1
# 8   0.081056               (cake)       1
# 12  0.059992            (chicken)       1
# 13  0.163845          (chocolate)       1
# 15  0.080389            (cookies)       1
# 16  0.051060        (cooking oil)       1
# 19  0.179709               (eggs)       1
# 22  0.079323           (escalope)       1
# 24  0.170911       (french fries)       1
# 29  0.063325    (frozen smoothie)       1
# 30  0.095321  (frozen vegetables)       1
# 31  0.052393      (grated cheese)       1
# 32  0.132116          (green tea)       1
# 33  0.098254        (ground beef)       1
# 41  0.076523     (low fat yogurt)       1
# 45  0.129583               (milk)       1
# 46  0.238368      (mineral water)       1
# 52  0.065858          (olive oil)       1
# 53  0.095054           (pancakes)       1
# 61  0.071457             (shrimp)       1
# 62  0.050527               (soup)       1
# 63  0.174110          (spaghetti)       1
# 67  0.068391           (tomatoes)       1
# 68  0.062525             (turkey)       1
# 72  0.058526   (whole wheat rice)       1

# %%
rules = association_rules(freq_rules, metric="lift", min_threshold=1.2)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
rules.sort_values("lift",ascending=False)
# Out:
#                     antecedents  ... consequents_length
# 159             (herb & pepper)  ...                  1
# 158               (ground beef)  ...                  1
# 326  (spaghetti, mineral water)  ...                  1
# 327               (ground beef)  ...                  2
# 341                 (olive oil)  ...                  2
# ..                          ...  ...                ...
# 100                      (eggs)  ...                  1
# 152                    (shrimp)  ...                  1
# 153                 (green tea)  ...                  1
# 109              (french fries)  ...                  1
# 108                  (escalope)  ...                  1
#
# [348 rows x 11 columns]

# %%
rules.sort_values("confidence",ascending=False)
# Out:
#                    antecedents  ... consequents_length
# 284        (ground beef, eggs)  ...                  1
# 318        (ground beef, milk)  ...                  1
# 260   (chocolate, ground beef)  ...                  1
# 306  (frozen vegetables, milk)  ...                  1
# 214                     (soup)  ...                  1
# ..                         ...  ...                ...
# 209            (mineral water)  ...                  1
# 340            (mineral water)  ...                  2
# 39             (mineral water)  ...                  1
# 304            (mineral water)  ...                  2
# 289            (mineral water)  ...                  2
#
# [348 rows x 11 columns]
